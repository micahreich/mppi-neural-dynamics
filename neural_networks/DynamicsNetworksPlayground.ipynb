# %%
import numpy as np
from scipy import integrate
import matplotlib.pyplot as plt

# %%
m = 1
l = 1
g = -9.81
b = 0.1

def dynamics(u):
    def dydt(y, t):
        theta, omega = y
        alpha = (-b * omega + u[0] + m * g * l * np.sin(theta)) / (m * l**2)

        return np.array([omega, alpha])

    return dydt

# %%
action = [0]

initial_state = np.array([np.pi - 1e-3, -1])
dynamics_ode = dynamics(action)
times = np.linspace(0, 10, 10 * 10 + 1)

next_state = scipy.integrate.odeint(dynamics_ode, initial_state, times)

# %%
xs = next_state[:, 0]
plt.plot(times, xs)
